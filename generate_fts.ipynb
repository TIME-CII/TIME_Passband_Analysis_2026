# %%
from fts import passband_compute
# Out:
# /Users/xenexjoshi/TIME-analysis-2026_deployment_dev/venv/lib/python3.11/site-packages/erfa/core.py:133: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#   warn(f'ERFA function "{func_name}" yielded {wmsg}', ErfaWarning)

# %%
# MCE 0
MCE = 0
obs_ids = [1772484062] # Observation id here
file_paths = ["MCE filepath goes here..."]
encoder_paths = ["Corresponding encoder filepath goes here..."]
V_MM = 2

# %%
passband_compute(MCE, obs_ids, file_paths, encoder_paths, V_MM)
breakpoint()
# Out:
# /Volumes/XJ_DATA/hk_1772484062
# /Volumes/XJ_DATA/mce_1772484062
# /Users/xenexjoshi/TIME-analysis-2026_deployment_dev/timesoft/timestream/timestream_tools.py:549: UserWarning: Commanded position didn't get converted to match data
#   warnings.warn("Commanded position didn't get converted to match data")
# Completed loading data from 1772484062 : MCE0.
# /Users/xenexjoshi/TIME-analysis-2026_deployment_dev/fts.py:138: RuntimeWarning: All-NaN slice encountered
#   avg_bin_ys = np.nanmedian(bin_ys, axis=0)
# Finished generating bandpass figures.
# Finished saving band stats.
# Obs_ID: 1772484062  |  Failures: 942

# %%
# MCE 1
MCE = 1
obs_ids = [1772484062] # Observation id here
file_paths = ["MCE filepath goes here..."]
encoder_paths = ["Corresponding encoder filepath goes here..."]
V_MM = 2

# %%
passband_compute(MCE, obs_ids, file_paths, encoder_paths, V_MM)
